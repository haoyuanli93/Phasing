# %% [markdown]
# # Develop GPU-based HIO algorithm

# %%
from IPython.core.display import display, HTML
import numpy as np
import numpy.fft as fft
import skimage.measure as sm
import matplotlib.pyplot as plt
from math import pi
import imageio
from numba import cuda
import numpy
import math

display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Load the test image

# %%
#Read in source image
source = plt.imread("../tests/samples/Albert_Einstein.jpg",format="jpg")

# Because the original image is too large downsample the image by a factor of 20
source = sm.block_reduce(source, (20,20), np.mean)

#Show this figure
fig = plt.figure(figsize=(5,5))
plt.imshow(source, cmap = "gray")
plt.colorbar()
plt.title("Image of Albert Einstein")
print("The image size is %d by %d"%(source.shape[0], source.shape[1]))
# Out:
# The image size is 217 by 163

# %% [markdown]
# # Simulate over-sampling

# %%
## pad_len is the size of the support
pad_len = len(source)
padded = np.pad(source, ((pad_len, pad_len),(pad_len, pad_len)), 'constant', 
                constant_values=((0,0),(0,0)))

#Show this figure
fig = plt.figure(figsize=(5,5))
plt.imshow(padded, cmap="gray")
plt.colorbar()
plt.title("Image of Albert Einstein")
print("The image size is %d by %d"%(padded.shape[0], padded.shape[1]))
# Out:
# The image size is 651 by 597

# %%
# Calculate the fourier transformation
ft = fft.fft2(padded)

#simulate diffraction pattern
magnitude = np.abs(ft)

length, width = padded.shape

#keep track of where the image is vs the padding
mask = np.zeros_like(padded, dtype=np.int64)
mask[pad_len:2*pad_len, pad_len:2*pad_len] = 1
#Show this mask
fig = plt.figure(figsize=(5,5))
plt.imshow(mask, cmap="gray")
plt.colorbar()
plt.title("Image of Albert Einstein")
print("The image size is %d by %d"%(mask.shape[0], mask.shape[1]))

diffract = np.copy(magnitude)
# Out:
# The image size is 651 by 597

# %%
#Initial guess using random phase info
guess = diffract * np.exp(1j * np.random.rand(length,width) * 2 * pi)

inv = fft.ifft2(guess)
inv = np.real(inv)
prev = np.copy(inv)

#number of iterations
r = 801

#step size parameter
beta = 0.8

# Begin the loop
for s in range(1,r):
    #apply fourier domain constraints
    update = diffract * np.exp(1j * np.angle(guess)) 
    
    inv = fft.ifft2(update)
    inv = np.real(inv)
    
    ## This part need to be vectorize
    inv[(inv<0)&(mask==1)] = prev[(inv<0)&(mask==1)] - beta* inv[(inv<0)&(mask==1)]
    inv[mask==0] = prev[mask ==0 ] - beta*inv[mask ==0]
        
    prev = inv
    
    guess = fft.fft2(inv)
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [-67.06744325071281, 314.7071821864356]. Convert image to uint8 prior to saving to suppress this warning.
# 100
# WARNING:root:Lossy conversion from float64 to uint8. Range [-54.43547659570087, 295.8480010210888]. Convert image to uint8 prior to saving to suppress this warning.
# 200
# WARNING:root:Lossy conversion from float64 to uint8. Range [-54.841076613991326, 287.2272171740446]. Convert image to uint8 prior to saving to suppress this warning.
# 300
# WARNING:root:Lossy conversion from float64 to uint8. Range [-53.19131868293458, 268.5517920953893]. Convert image to uint8 prior to saving to suppress this warning.
# 400
# WARNING:root:Lossy conversion from float64 to uint8. Range [-52.65351538525544, 279.7466577765514]. Convert image to uint8 prior to saving to suppress this warning.
# 500
# WARNING:root:Lossy conversion from float64 to uint8. Range [-53.915051446721655, 271.80228790527764]. Convert image to uint8 prior to saving to suppress this warning.
# 600
# WARNING:root:Lossy conversion from float64 to uint8. Range [-52.99413639189815, 270.0880467445901]. Convert image to uint8 prior to saving to suppress this warning.
# 700
# WARNING:root:Lossy conversion from float64 to uint8. Range [-51.23695934595896, 263.52790278200627]. Convert image to uint8 prior to saving to suppress this warning.
# 800
